# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import  accuracy_score, recall_score, roc_auc_score, f1_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import ComplementNB, GaussianNB, CategoricalNB, BernoulliNB, MultinomialNB

# %%
dir_path =r"C:/Users/User/Desktop/finalP/final_result/robustness_test_1.5/datasets/"
r_weekly_data=pd.read_csv(dir_path+'(raw)Weekly_data_1.5.csv')

# %%
#normalize data
cols_to_norm = ['future_return','volume','amount','BASIS','index_turnover_rate','short_balance_ratio','pli','t_spread','RSI','index_trading_volume','inventory']
r_weekly_data[cols_to_norm] = r_weekly_data[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
r_weekly_data.head()
# Out:
#    week  future_return    volume  inventory    amount     BASIS  \
# 0     1            NaN  0.264808   0.000000  0.264808  0.927600
# 1     2       0.487179  0.592076   0.368713  0.592076  0.865631
# 2     3       0.569215  0.602021   0.446166  0.602021  0.872123
# 3     4       0.528259  0.609204   0.449680  0.609204  0.922674
# 4     5       0.511708  0.679653   0.511005  0.679653  0.830668
#
#    index_turnover_rate  short_balance_ratio   pli  t_spread       RSI  \
# 0             0.119796             0.000000  0.00  1.000000  0.000000
# 1             0.212404             0.000022  0.20  0.987335  0.524424
# 2             0.141037             0.000102  0.20  0.967770  0.183508
# 3             0.145285             0.000108  0.25  0.953524  0.170384
# 4             0.131691             0.000235  0.60  0.934460  0.484418
#
#    index_trading_volume  CCt+1
# 0              0.069764    0.0
# 1              0.525772    0.0
# 2              0.461334    0.0
# 3              0.409622    0.0
# 4              0.431835    1.0

# %%
r_weekly_data = r_weekly_data.dropna()
r_weekly_data = r_weekly_data.drop(['week'], axis=1)
r_weekly_data
# Out:
#      future_return    volume  inventory    amount     BASIS  \
# 1         0.487179  0.592076   0.368713  0.592076  0.865631
# 2         0.569215  0.602021   0.446166  0.602021  0.872123
# 3         0.528259  0.609204   0.449680  0.609204  0.922674
# 4         0.511708  0.679653   0.511005  0.679653  0.830668
# 5         0.563284  0.703962   0.530620  0.703962  0.855181
# ..             ...       ...        ...       ...       ...
# 646       0.613547  0.547822   0.959165  0.547822  0.809675
# 647       0.710439  0.560717   0.964331  0.560717  0.814171
# 648       0.745374  0.570798   0.972305  0.570798  0.803590
# 649       0.646556  0.573218   0.962424  0.573218  0.812818
# 650       0.580039  0.540630   0.962895  0.540630  0.836030
#
#      index_turnover_rate  short_balance_ratio   pli  t_spread       RSI  \
# 1               0.212404             0.000022  0.20  0.987335  0.524424
# 2               0.141037             0.000102  0.20  0.967770  0.183508
# 3               0.145285             0.000108  0.25  0.953524  0.170384
# 4               0.131691             0.000235  0.60  0.934460  0.484418
# 5               0.123195             0.000378  0.40  0.884720  0.428781
# ..                   ...                  ...   ...       ...       ...
# 646             0.118097             0.595693  0.60  0.420387  0.240647
# 647             0.153781             0.512961  0.60  0.445867  0.618736
# 648             0.159728             0.464528  0.80  0.418403  0.778353
# 649             0.083263             0.547433  0.40  0.406039  0.236344
# 650             0.052676             0.670958  0.40  0.391212  0.073265
#
#      index_trading_volume  CCt+1
# 1                0.525772    0.0
# 2                0.461334    0.0
# 3                0.409622    0.0
# 4                0.431835    1.0
# 5                0.409571    1.0
# ..                    ...    ...
# 646              0.675789    0.0
# 647              0.738649    0.0
# 648              0.747785    0.0
# 649              0.678701    0.0
# 650              0.626639    0.0
#
# [650 rows x 12 columns]

# %%
X = r_weekly_data.iloc[:, :-1]  # Features (all columns except the last one)
y = r_weekly_data.iloc[:, -1]   # Labels (last column)
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)
balanced_df = pd.concat([X_resampled, y_resampled], axis=1)

# %%
#balanced_df.to_csv("balanced_df_weekly.csv")
balanced_df
# Out:
#       future_return    volume  inventory    amount     BASIS  \
# 0          0.487179  0.592076   0.368713  0.592076  0.865631
# 1          0.569215  0.602021   0.446166  0.602021  0.872123
# 2          0.528259  0.609204   0.449680  0.609204  0.922674
# 3          0.511708  0.679653   0.511005  0.679653  0.830668
# 4          0.563284  0.703962   0.530620  0.703962  0.855181
# ...             ...       ...        ...       ...       ...
# 1049       0.587290  0.360292   0.692219  0.360292  0.603917
# 1050       0.517006  0.591679   0.959728  0.591679  0.784000
# 1051       0.656764  0.559959   0.947382  0.559959  0.784241
# 1052       0.650764  0.341781   0.686135  0.341781  0.761764
# 1053       0.641734  0.553312   0.960465  0.553312  0.746088
#
#       index_turnover_rate  short_balance_ratio       pli  t_spread       RSI  \
# 0                0.212404             0.000022  0.200000  0.987335  0.524424
# 1                0.141037             0.000102  0.200000  0.967770  0.183508
# 2                0.145285             0.000108  0.250000  0.953524  0.170384
# 3                0.131691             0.000235  0.600000  0.934460  0.484418
# 4                0.123195             0.000378  0.400000  0.884720  0.428781
# ...                   ...                  ...       ...       ...       ...
# 1049             0.199091             0.024274  0.453890  0.555096  0.455598
# 1050             0.166590             0.579561  0.200000  0.523639  0.299373
# 1051             0.076469             0.610342  0.200000  0.534896  0.154390
# 1052             0.113968             0.055579  0.375726  0.353322  0.455172
# 1053             0.165768             0.556507  0.800000  0.494121  0.309351
#
#       index_trading_volume  CCt+1
# 0                 0.525772    0.0
# 1                 0.461334    0.0
# 2                 0.409622    0.0
# 3                 0.431835    1.0
# 4                 0.409571    1.0
# ...                    ...    ...
# 1049              0.641083    1.0
# 1050              0.778145    1.0
# 1051              0.687144    1.0
# 1052              0.620145    1.0
# 1053              0.780784    1.0
#
# [1054 rows x 12 columns]

# %%
# Using balanced df to make predictions
X = r_weekly_data.iloc[:, :-1]  # Features (all columns except the last one)
y = r_weekly_data.iloc[:, -1]   # Labels (last column)

X = balanced_df.iloc[:, :-1]
y = balanced_df.iloc[:, -1]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=13)

# %%
cnb = ComplementNB().fit(X_train, y_train)  # fitting 
prediction = cnb.predict(X_test)  # predictions
prediction_train = cnb.predict(X_train)

accuracy = accuracy_score(y_test, prediction)
recall = recall_score(y_test, prediction)
roc_auc = roc_auc_score(y_test, prediction)
f1 = f1_score(y_test, prediction)
print("Accuracy:", accuracy)
print("ROC-AUC:", roc_auc)
print("F1 score:", f1)
print("Recall:", recall)
# Out:
# Accuracy: 0.6056782334384858
# ROC-AUC: 0.6052463975798106
# F1 score: 0.5421245421245422
# Recall: 0.46835443037974683

# %%
gnb = GaussianNB().fit(X_train, y_train)
prediction = gnb.predict(X_test)  # predictions
prediction_train = gnb.predict(X_train)

accuracy = accuracy_score(y_test, prediction)
recall = recall_score(y_test, prediction)
roc_auc = roc_auc_score(y_test, prediction)
f1 = f1_score(y_test, prediction)
print("Accuracy:", accuracy)
print("ROC-AUC:", roc_auc)
print("F1 score:", f1)
print("Recall:", recall)
# Out:
# Accuracy: 0.6908517350157729
# ROC-AUC: 0.6905302125626942
# F1 score: 0.6549295774647887
# Recall: 0.5886075949367089

# %%
#robustness
robust_500 = pd.read_csv(dir_path+'500_data_weekly_1.5.csv')
#drop NaN
robust_500 = robust_500.dropna()
#drop week column
robust_500 = robust_500.drop(['week'], axis=1)
robust_500.head()
cols_to_norm = ['future_return','volume','amount','basis','index_turnover_rate','short_balance_ratio','pli','t_spread','rsi','index_trading_volunme','inventory']
robust_500[cols_to_norm] = robust_500[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
X_robust = robust_500.iloc[:, :-1]  # Features (all columns except the last one)
y_robust = robust_500.iloc[:, -1]   # Labels (last column)
smote = SMOTE(random_state=42)
X_resampled_robust, y_resampled_robust = smote.fit_resample(X_robust, y_robust)

# %%
# ComplementNB robustness 
prediction = cnb.predict(X_resampled_robust)  # predictions
accuracy = accuracy_score(y_resampled_robust, prediction)
recall = recall_score(y_resampled_robust, prediction)
roc_auc = roc_auc_score(y_resampled_robust, prediction)
f1 = f1_score(y_resampled_robust, prediction)
print("ComplementNB robustness")
print("Accuracy:", accuracy)
print("ROC-AUC:", roc_auc)
print("F1 score:", f1)
print("Recall:", recall)
print(" ")

# GaussianNB robustness
prediction = gnb.predict(X_resampled_robust)  # predictions
accuracy = accuracy_score(y_resampled_robust, prediction)
recall = recall_score(y_resampled_robust, prediction)
roc_auc = roc_auc_score(y_resampled_robust, prediction)
f1 = f1_score(y_resampled_robust, prediction)
print("GaussianNB robustness")
print("Accuracy:", accuracy)
print("ROC-AUC:", roc_auc)
print("F1 score:", f1)
print("Recall:", recall)
print(" ")

# MultinomialNB robustness
prediction=clf1.predict(X_resampled_robust)
accuracy = accuracy_score(y_resampled_robust, prediction)
recall = recall_score(y_resampled_robust, prediction)
roc_auc = roc_auc_score(y_resampled_robust, prediction)
f1 = f1_score(y_resampled_robust, prediction)
print("MultinomialNB robustness")
print("Accuracy:", accuracy)
print("ROC-AUC:", roc_auc)
print("F1 score:", f1)
print("Recall:", recall)
print(" ")


# BernoulliNB robustness
prediction=clf2.predict(X_resampled_robust)
accuracy = accuracy_score(y_resampled_robust, prediction)
recall = recall_score(y_resampled_robust, prediction)
roc_auc = roc_auc_score(y_resampled_robust, prediction)
f1 = f1_score(y_resampled_robust, prediction)
print("BernoulliNB robustness")
print("Accuracy:", accuracy)
print("ROC-AUC:", roc_auc)
print("F1 score:", f1)
print("Recall:", recall)
print(" ")
# Out:
# ComplementNB robustness
# Accuracy: 0.5654205607476636
# ROC-AUC: 0.5654205607476636
# F1 score: 0.5507246376811593
# Recall: 0.5327102803738317
#
# GaussianNB robustness
# Accuracy: 0.5950155763239875
# ROC-AUC: 0.5950155763239876
# F1 score: 0.644808743169399
# Recall: 0.735202492211838
#
# MultinomialNB robustness
# Accuracy: 0.5685358255451713
# ROC-AUC: 0.5685358255451713
# F1 score: 0.5582137161084529
# Recall: 0.5451713395638629
#
# BernoulliNB robustness
# Accuracy: 0.5093457943925234
# ROC-AUC: 0.5093457943925234
# F1 score: 0.6687697160883281
# Recall: 0.9906542056074766
